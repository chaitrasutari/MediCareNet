# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from pathlib import Path

# %%
# Load the cleaned dataset
file_path = "../data/processed/cleaned_data.csv"
df = pd.read_csv(file_path)

# Show basic info and first few rows to confirm structure
df.info(), df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 48 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   race                      99492 non-null  object
#  1   gender                    99492 non-null  object
#  2   age                       99492 non-null  object
#  3   admission_type_id         99492 non-null  int64
#  4   discharge_disposition_id  99492 non-null  int64
#  5   admission_source_id       99492 non-null  int64
#  6   time_in_hospital          99492 non-null  int64
#  7   num_lab_procedures        99492 non-null  int64
#  8   num_procedures            99492 non-null  int64
#  9   num_medications           99492 non-null  int64
#  10  number_outpatient         99492 non-null  int64
#  11  number_emergency          99492 non-null  int64
#  12  number_inpatient          99492 non-null  int64
#  13  diag_1                    99492 non-null  object
#  14  diag_2                    99492 non-null  object
#  15  diag_3                    99492 non-null  object
#  16  number_diagnoses          99492 non-null  int64
#  17  max_glu_serum             99492 non-null  int64
#  18  A1Cresult                 99492 non-null  int64
#  19  metformin                 99492 non-null  object
#  20  repaglinide               99492 non-null  object
#  21  nateglinide               99492 non-null  object
#  22  chlorpropamide            99492 non-null  object
#  23  glimepiride               99492 non-null  object
#  24  acetohexamide             99492 non-null  object
#  25  glipizide                 99492 non-null  object
#  26  glyburide                 99492 non-null  object
#  27  tolbutamide               99492 non-null  object
#  28  pioglitazone              99492 non-null  object
#  29  rosiglitazone             99492 non-null  object
#  30  acarbose                  99492 non-null  object
#  31  miglitol                  99492 non-null  object
#  32  troglitazone              99492 non-null  object
#  33  tolazamide                99492 non-null  object
#  34  examide                   99492 non-null  object
#  35  citoglipton               99492 non-null  object
#  36  insulin                   99492 non-null  object
#  37  glyburide-metformin       99492 non-null  object
#  38  glipizide-metformin       99492 non-null  object
#  39  glimepiride-pioglitazone  99492 non-null  object
#  40  metformin-rosiglitazone   99492 non-null  object
#  41  metformin-pioglitazone    99492 non-null  object
#  42  change                    99492 non-null  object
#  43  diabetesMed               99492 non-null  object
#  44  readmitted_30             99492 non-null  int64
#  45  diag_1_category           99492 non-null  object
#  46  diag_2_category           99492 non-null  object
#  47  diag_3_category           99492 non-null  object
# dtypes: int64(14), object(34)
# memory usage: 36.4+ MB
# (None,
#                race  gender      age  admission_type_id  \
#  0        Caucasian  Female   [0-10)                  6
#  1        Caucasian  Female  [10-20)                  1
#  2  AfricanAmerican  Female  [20-30)                  1
#  3        Caucasian    Male  [30-40)                  1
#  4        Caucasian    Male  [40-50)                  1
#
#     discharge_disposition_id  admission_source_id  time_in_hospital  \
#  0                        25                    1                 1
#  1                         1                    7                 3
#  2                         1                    7                 2
#  3                         1                    7                 2
#  4                         1                    7                 1
#
#     num_lab_procedures  num_procedures  num_medications  ...  \
#  0                  41               0                1  ...
#  1                  59               0               18  ...
#  2                  11               5               13  ...
#  3                  44               1               16  ...
#  4                  51               0                8  ...
#
#     glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  \
#  0                   No                        No                       No
#  1                   No                        No                       No
#  2                   No                        No                       No
#  3                   No                        No                       No
#  4                   No                        No                       No
#
#    metformin-pioglitazone change diabetesMed  readmitted_30  diag_1_category  \
#  0                     No     No          No              0         Diabetes
#  1                     No     Ch         Yes              0            Other
#  2                     No     No         Yes              0            Other
#  3                     No     Ch         Yes              0            Other
#  4                     No     Ch         Yes              0        Neoplasms
#
#     diag_2_category diag_3_category
#  0          Unknown         Unknown
#  1         Diabetes           Other
#  2         Diabetes    Supplemental
#  3         Diabetes     Circulatory
#  4        Neoplasms        Diabetes
#
#  [5 rows x 48 columns])

# %%
# 1. Remove target leakage rows based on discharge_disposition_id
leak_ids = [11, 13, 14, 19, 20, 21]
df = df[~df['discharge_disposition_id'].isin(leak_ids)]

# %%
# 2. Cap outliers for 'num_medications' at 95th percentile
cap = df['num_medications'].quantile(0.95)
df['num_medications'] = df['num_medications'].clip(upper=cap)

# %%
# 3. Create binned feature 'number_inpatient_bin'
df['number_inpatient_bin'] = pd.cut(
    df['number_inpatient'], 
    bins=[-1, 0, 2, 100], 
    labels=["0", "1-2", "3+"]
)

# %%
# 3. Create binned feature 'number_inpatient_bin'
df['number_inpatient_bin'] = pd.cut(
    df['number_inpatient'], 
    bins=[-1, 0, 2, 100], 
    labels=["0", "1-2", "3+"]
)

# %%
# 4. Create composite feature 'total_visits'
df['total_visits'] = df['number_inpatient'] + df['number_outpatient'] + df['number_emergency']

# %%
df.head()
# Out:
#               race  gender      age  admission_type_id  \
# 0        Caucasian  Female   [0-10)                  6
# 1        Caucasian  Female  [10-20)                  1
# 2  AfricanAmerican  Female  [20-30)                  1
# 3        Caucasian    Male  [30-40)                  1
# 4        Caucasian    Male  [40-50)                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                        25                    1                 1
# 1                         1                    7                 3
# 2                         1                    7                 2
# 3                         1                    7                 2
# 4                         1                    7                 1
#
#    num_lab_procedures  num_procedures  num_medications  ...  \
# 0                  41               0                1  ...
# 1                  59               0               18  ...
# 2                  11               5               13  ...
# 3                  44               1               16  ...
# 4                  51               0                8  ...
#
#    metformin-rosiglitazone  metformin-pioglitazone  change diabetesMed  \
# 0                       No                      No      No          No
# 1                       No                      No      Ch         Yes
# 2                       No                      No      No         Yes
# 3                       No                      No      Ch         Yes
# 4                       No                      No      Ch         Yes
#
#   readmitted_30 diag_1_category  diag_2_category  diag_3_category  \
# 0             0        Diabetes          Unknown          Unknown
# 1             0           Other         Diabetes            Other
# 2             0           Other         Diabetes     Supplemental
# 3             0           Other         Diabetes      Circulatory
# 4             0       Neoplasms        Neoplasms         Diabetes
#
#    number_inpatient_bin total_visits
# 0                     0            0
# 1                     0            0
# 2                   1-2            3
# 3                     0            0
# 4                     0            0
#
# [5 rows x 50 columns]

# %%
# 5. Group rare categories (<1%) as 'Other' for categorical variables
# Example for a generic categorical column 'some_cat_column'
def group_rare_categories(series, threshold=0.01):
    freq = series.value_counts(normalize=True)
    rare_labels = freq[freq < threshold].index
    return series.apply(lambda x: 'Other' if x in rare_labels else x)

# %%
print(df.columns)
# Out:
# Index(['race', 'gender', 'age', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted_30',
#        'diag_1_category', 'diag_2_category', 'diag_3_category',
#        'number_inpatient_bin', 'total_visits'],
#       dtype='object')

# %%
# Apply for relevant categorical columns (replace 'cat_cols' with your columns)
cat_cols = ['race', 'diag_1_category', 'diag_2_category', 'diag_3_category']

for col in cat_cols:
    if col in df.columns:
        df[col] = group_rare_categories(df[col])

# %%
# 6. Create interaction features
df['age_inpatient_interaction'] = df['age'].astype(str) + '_' + df['number_inpatient_bin'].astype(str)
df['diabetes_insulin_combo'] = df['diabetesMed'].astype(str) + '_' + df['insulin'].astype(str)

# %%
print(df.columns)
# Out:
# Index(['race', 'gender', 'age', 'admission_type_id',
#        'discharge_disposition_id', 'admission_source_id', 'time_in_hospital',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted_30',
#        'diag_1_category', 'diag_2_category', 'diag_3_category',
#        'number_inpatient_bin', 'total_visits', 'age_inpatient_interaction',
#        'diabetes_insulin_combo'],
#       dtype='object')

# %%
print(df.head())
# Out:
#               race  gender      age  admission_type_id  \
# 0        Caucasian  Female   [0-10)                  6
# 1        Caucasian  Female  [10-20)                  1
# 2  AfricanAmerican  Female  [20-30)                  1
# 3        Caucasian    Male  [30-40)                  1
# 4        Caucasian    Male  [40-50)                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                        25                    1                 1
# 1                         1                    7                 3
# 2                         1                    7                 2
# 3                         1                    7                 2
# 4                         1                    7                 1
#
#    num_lab_procedures  num_procedures  num_medications  ...  change  \
# 0                  41               0                1  ...      No
# 1                  59               0               18  ...      Ch
# 2                  11               5               13  ...      No
# 3                  44               1               16  ...      Ch
# 4                  51               0                8  ...      Ch
#
#    diabetesMed  readmitted_30 diag_1_category diag_2_category diag_3_category  \
# 0           No              0        Diabetes           Other         Unknown
# 1          Yes              0           Other        Diabetes           Other
# 2          Yes              0           Other        Diabetes    Supplemental
# 3          Yes              0           Other        Diabetes     Circulatory
# 4          Yes              0       Neoplasms       Neoplasms        Diabetes
#
#    number_inpatient_bin  total_visits  age_inpatient_interaction  \
# 0                     0             0                   [0-10)_0
# 1                     0             0                  [10-20)_0
# 2                   1-2             3                [20-30)_1-2
# 3                     0             0                  [30-40)_0
# 4                     0             0                  [40-50)_0
#
#   diabetes_insulin_combo
# 0                  No_No
# 1                 Yes_Up
# 2                 Yes_No
# 3                 Yes_Up
# 4             Yes_Steady
#
# [5 rows x 52 columns]

# %%
print(df.columns.tolist())
# Out:
# ['gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted_30', 'diag_1_category', 'diag_2_category', 'diag_3_category', 'total_visits', 'age_[10-20)', 'age_[20-30)', 'age_[30-40)', 'age_[40-50)', 'age_[50-60)', 'age_[60-70)', 'age_[70-80)', 'age_[80-90)', 'age_[90-100)', 'number_inpatient_bin_1-2', 'number_inpatient_bin_3+', 'race_Caucasian', 'race_Hispanic', 'race_Other', 'age_inpatient_interaction_[0-10)_1-2', 'age_inpatient_interaction_[10-20)_0', 'age_inpatient_interaction_[10-20)_1-2', 'age_inpatient_interaction_[10-20)_3+', 'age_inpatient_interaction_[20-30)_0', 'age_inpatient_interaction_[20-30)_1-2', 'age_inpatient_interaction_[20-30)_3+', 'age_inpatient_interaction_[30-40)_0', 'age_inpatient_interaction_[30-40)_1-2', 'age_inpatient_interaction_[30-40)_3+', 'age_inpatient_interaction_[40-50)_0', 'age_inpatient_interaction_[40-50)_1-2', 'age_inpatient_interaction_[40-50)_3+', 'age_inpatient_interaction_[50-60)_0', 'age_inpatient_interaction_[50-60)_1-2', 'age_inpatient_interaction_[50-60)_3+', 'age_inpatient_interaction_[60-70)_0', 'age_inpatient_interaction_[60-70)_1-2', 'age_inpatient_interaction_[60-70)_3+', 'age_inpatient_interaction_[70-80)_0', 'age_inpatient_interaction_[70-80)_1-2', 'age_inpatient_interaction_[70-80)_3+', 'age_inpatient_interaction_[80-90)_0', 'age_inpatient_interaction_[80-90)_1-2', 'age_inpatient_interaction_[80-90)_3+', 'age_inpatient_interaction_[90-100)_0', 'age_inpatient_interaction_[90-100)_1-2', 'age_inpatient_interaction_[90-100)_3+', 'diabetes_insulin_combo_Yes_Down', 'diabetes_insulin_combo_Yes_No', 'diabetes_insulin_combo_Yes_Steady', 'diabetes_insulin_combo_Yes_Up']

# %%
# List of numerical columns to scale
num_cols = [
    'num_lab_procedures',
    'num_procedures',
    'num_medications',
    'time_in_hospital',
    'number_inpatient',
    'number_outpatient',
    'number_emergency',
    'total_visits'
]

# Initialize the scaler
scaler = StandardScaler()

# Fit and transform only if all columns exist to avoid errors
existing_num_cols = [col for col in num_cols if col in df.columns]

df[existing_num_cols] = scaler.fit_transform(df[existing_num_cols])

# %%
output_path = Path("../data/processed/feature_engineered_data.csv")

# %%
output_path.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(output_path, index=False)

print(f"Cleaned data saved to: {output_path}")
print(f"Final shape: {df.shape}")
# Out:
# Cleaned data saved to: ..\data\processed\feature_engineered_data.csv
# Final shape: (97108, 93)
